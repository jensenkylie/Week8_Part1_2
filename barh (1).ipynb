# %%
# %matplotlib inline

# %% [markdown]
# # Horizontal bar chart
#
#
# This example showcases a simple horizontal bar chart.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Numbers of Duck Species Counted In 1 Day of Survey


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Mallard', 'Blue Winged Teal', 'Gadwall', 'Wood Duck', 'Green Winged Teal')
y_pos = np.arange(len(people))
performance = ('4', '6', '10', '12', '15') 

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of Ducks')
ax.set_title('How Many Ducks Did We See Today?')

plt.show()
